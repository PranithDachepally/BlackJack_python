# %%
import random

suits = ('Hearts','Diamonds','Spades','Clubs')
ranks = ('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')
values = {'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':10,'Queen':10,'King':10,'Ace':11}
playing = True


class Deck():
    
    def __init__(self):
        self.deck=[]
        for s in suits:
            for r in ranks:
                self.deck.append(r + ' of ' + s)             
    def __str__(self):
        return ''.join(str(e)+'\n' for e in self.deck)

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        card = self.deck.pop()
        return card

class Hand:
 
    def __init__(self):
        self.cards = []
        self.aces = 0  
        self.value = 0
        
    def add_card(self,card):
        self.cards.append(card)
        self.value += values[str(card.split(" ")[0])]
    
    def adjust_for_ace(self):
        global value
        if(self.value > 17 and self.aces>1):
            self.value = self.value-10
            self.aces = self.aces-1
            
class Chips:
    
    def __init__(self):
        self.total = 100
        self.bet = 0
        
    def win_bet(self):
        self.total = self.total + self.bet
    
    def lose_bet(self):
        self.total = self.total - self.bet
    
def take_bet(chips):
    while True:
        try:
            chips.bet = int(input('enter the betting amount :  '))
        except ValueError:
            print('Sorry enter a integer value')   
        else:
            if(chips.bet > chips.total):
                print('you dont have sufficient chips')
            else:
                break

def hit(desk,hand):
    hand.add_card(desk.deal())
    hand.adjust_for_ace()
        
def hit_or_stand(deck,hand):
    global playing
    
    while True:
        x = input('hit or stand :  ')
        if(x.lower().startswith('h')):
            hit(deck,hand)         
        elif(x.lower().startswith('s')):  
            print('player stands.Dealer is playing')
            playing = False
        else:
            print('Sorry, try again')
            continue
        break

def show_some(player,dealer):
    print('\nshowing cards')
    print('player cards: '+str(player.cards))
    print('dealer cards: '+str(dealer.cards[1])) 
    
def show_all(player,dealer):
    print('\nshowing cards')
    print('player cards: '+str(player.cards))
    print('player value : '+str(player.value))
    print('dealer cards: '+str(dealer.cards)) 
    print('dealer value : '+str(dealer.value))
    
def player_busts(player,dealer,chips):
    print('Player Bust!!!')
    chips.lose_bet()

def player_wins(player,dealer,chips):
    print('Player won!')
    chips.win_bet()
    
def dealer_busts(player,dealer,chips):
    print('Dealer Bust!!!')
    chips.win_bet()
    
def dealer_wins(player,dealer,chips):
    print('Dealer won!')
    chips.lose_bet()
    
def push(player,dealer):
    print('Draw!')    
    
while True:
    
    print('Welcome to BlackJack!')
    
    # Create & shuffle the deck, deal two cards to each player
    deck = Deck()
    deck.shuffle()
    
    player = Hand()
    player.add_card(deck.deal())
    player.add_card(deck.deal())
    
    dealer = Hand()
    dealer.add_card(deck.deal())
    dealer.add_card(deck.deal())
    
    player_chips = Chips()
    
    take_bet(player_chips)
    
    show_some(player,dealer)
    
    while playing:
        
        hit_or_stand(deck,player)
        
        show_some(player,dealer)
        
        if player.value > 21:
            player_busts(player,dealer,player_chips)
            break
        
    if player.value <= 21:
        
        while dealer.value < 17 :
            hit(deck,dealer)
        
        show_all(player,dealer)
        
        if dealer.value > 21 :
            dealer_busts(player,dealer,player_chips)
        elif dealer.value > player.value:
            dealer_wins(player,dealer,player_chips)
        elif dealer.value < player.value :
            player_wins(player,dealer,player_chips)
        else:
            push(player,dealer)
        
    print('Player chips : ',player_chips.total)
    
    play_again = input('Would you like to play again(yes/no) : ')
    
    if (play_again.lower().startswith('y')):
        playing = True
        continue
    else:
        print('Thanks for playing!')
        break
# Out:
# Welcome to BlackJack!
# enter the betting amount :  100
#
# showing cards
# player cards: ['Two of Diamonds', 'King of Diamonds']
# dealer cards: Five of Spades
# hit or stand :  hit
#
# showing cards
# player cards: ['Two of Diamonds', 'King of Diamonds', 'Two of Clubs']
# dealer cards: Five of Spades
# hit or stand :  hit
#
# showing cards
# player cards: ['Two of Diamonds', 'King of Diamonds', 'Two of Clubs', 'Ace of Spades']
# dealer cards: Five of Spades
# Player Bust!!!
# Player chips :  0
# Would you like to play again(yes/no) : y
# Welcome to BlackJack!
# enter the betting amount :  100
#
# showing cards
# player cards: ['Queen of Hearts', 'King of Clubs']
# dealer cards: Ten of Hearts
# hit or stand :  stand
# player stands.Dealer is playing
#
# showing cards
# player cards: ['Queen of Hearts', 'King of Clubs']
# dealer cards: Ten of Hearts
#
# showing cards
# player cards: ['Queen of Hearts', 'King of Clubs']
# player value : 20
# dealer cards: ['Queen of Clubs', 'Ten of Hearts']
# dealer value : 20
# Draw!
# Player chips :  100
# Would you like to play again(yes/no) : yes
# Welcome to BlackJack!
# enter the betting amount :  100
#
# showing cards
# player cards: ['Six of Clubs', 'Ace of Diamonds']
# dealer cards: Nine of Diamonds
# hit or stand :  hit
#
# showing cards
# player cards: ['Six of Clubs', 'Ace of Diamonds', 'Queen of Spades']
# dealer cards: Nine of Diamonds
# Player Bust!!!
# Player chips :  0
# Would you like to play again(yes/no) : y
# Welcome to BlackJack!
# enter the betting amount :  hit
# Sorry enter a integer value
# enter the betting amount :  10
#
# showing cards
# player cards: ['Four of Diamonds', 'Seven of Spades']
# dealer cards: Five of Clubs
# hit or stand :  hit
#
# showing cards
# player cards: ['Four of Diamonds', 'Seven of Spades', 'Eight of Diamonds']
# dealer cards: Five of Clubs
# hit or stand :  stand
# player stands.Dealer is playing
#
# showing cards
# player cards: ['Four of Diamonds', 'Seven of Spades', 'Eight of Diamonds']
# dealer cards: Five of Clubs
#
# showing cards
# player cards: ['Four of Diamonds', 'Seven of Spades', 'Eight of Diamonds']
# player value : 19
# dealer cards: ['Jack of Spades', 'Five of Clubs', 'Five of Spades']
# dealer value : 20
# Dealer won!
# Player chips :  90
# Would you like to play again(yes/no) : yes
# Welcome to BlackJack!
# enter the betting amount :  100
#
# showing cards
# player cards: ['Seven of Diamonds', 'Three of Spades']
# dealer cards: Jack of Clubs
# hit or stand :  hit
#
# showing cards
# player cards: ['Seven of Diamonds', 'Three of Spades', 'Six of Hearts']
# dealer cards: Jack of Clubs
# hit or stand :  stand
# player stands.Dealer is playing
#
# showing cards
# player cards: ['Seven of Diamonds', 'Three of Spades', 'Six of Hearts']
# dealer cards: Jack of Clubs
#
# showing cards
# player cards: ['Seven of Diamonds', 'Three of Spades', 'Six of Hearts']
# player value : 16
# dealer cards: ['Six of Clubs', 'Jack of Clubs', 'Ten of Clubs']
# dealer value : 26
# Dealer Bust!!!
# Player chips :  200
# Would you like to play again(yes/no) : yes
# Welcome to BlackJack!
